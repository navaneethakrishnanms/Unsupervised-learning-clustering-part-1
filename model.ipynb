# %%
import pandas as pd
import numpy as np
df=pd.read_csv("cleaned_file.csv")
df.head()
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0 -1.314140          -1.269589  -0.383149         -1.008428
# 1  1.038458          -0.594878  -1.508970         -1.008428
# 2  0.843014           0.612641   0.505205          1.053009
# 3  0.076611           0.612641  -0.916257         -0.039942
# 4  0.605103           0.612641   0.794332         -1.008428
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                0.363676     -0.951258            -0.787010
# 1               -1.092643      1.397067            -1.285866
# 2               -1.092643     -0.951258             1.211921
# 3               -1.092643     -0.951258            -1.030565
# 4                1.244506     -0.951258             0.488440
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   -0.909176                         -0.622043
# 1                   -0.909176                         -1.012022
# 2                    1.724959                         -1.012022
# 3                   -0.111678                         -1.012022
# 4                   -0.909176                          0.782421
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0               -0.888595         -0.911869      -0.591497     -1.425204
# 1                1.102197          1.025584      -1.392628      0.914958
# 2               -0.888595         -0.911869       0.472489      1.002831
# 3               -0.888595         -0.911869      -0.886774     -1.216931
# 4               -0.888595         -0.911869       0.206232     -0.745788
#
#    PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT    TENURE
# 0 -1.290861         -0.815269         -0.693374  0.417156
# 1  1.302633          0.897031          1.179060  0.417156
# 2 -0.334356          0.462236         -0.693374  0.417156
# 3 -0.260117         -0.327426         -0.693374  0.417156
# 4  0.364597          1.532179         -0.693374  0.417156

# %%
from sklearn.cluster import KMeans

# Using PCA features
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans_labels = kmeans.fit_predict(X_pca)

print("KMeans cluster labels:", set(kmeans_labels))
